# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread('/Images/image2.jpg')

# Scaling operation
scale_factor = 1.5
img_scaled = cv2.resize(img, None, fx=scale_factor, fy=scale_factor, interpolation=cv2.INTER_LINEAR)

# Translation operation
rows, cols, _ = img.shape
M = np.float32([[1, 0, 100], [0, 1, 50]])
img_translated = cv2.warpAffine(img, M, (cols, rows))

# Rotation operation
M = cv2.getRotationMatrix2D((cols/2, rows/2), 90, 1)
img_rotated = cv2.warpAffine(img, M, (cols, rows))

# Plot the final images

# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
axs[0, 0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), aspect='auto')
axs[0, 1].imshow(cv2.cvtColor(img_scaled, cv2.COLOR_BGR2RGB), aspect='auto')
axs[1, 0].imshow(cv2.cvtColor(img_translated, cv2.COLOR_BGR2RGB), aspect='auto')
axs[1, 1].imshow(cv2.cvtColor(img_rotated, cv2.COLOR_BGR2RGB), aspect='auto')

# Set the title for each subplot
axs[0, 0].set_title('Original Image')
axs[0, 1].set_title('Scaled Image')
axs[1, 0].set_title('Translated Image')
axs[1, 1].set_title('Rotated Image')

plt.subplots_adjust(left=0.05, bottom=0.05, right=0.95, top=0.95, wspace=0.3, hspace=0.3)

plt.show()
